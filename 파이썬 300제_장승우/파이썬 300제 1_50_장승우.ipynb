# %%
#1
print("Hello World")
# Out:
# Hello World

# %%
#2
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
#3
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
#4
print('"C:\\Windows"')
# Out:
# "C:\Windows"

# %%
#5
print("안녕하세요.\n만나서\t\t반갑습니다.")
#\n은 줄바꿈, \t는 Tab
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
#6
print("오늘은","일요일")
#쉼표로 구분된 단어 사이에 공백이 삽입됨
# Out:
# 오늘은 일요일

# %%
#7
print("naver","kakao","sk","samsung", sep=";")
# Out:
# naver;kakao;sk;samsung

# %%
#8
print("naver","kakao","sk","samsung", sep="\\")
# Out:
# naver\kakao\sk\samsung

# %%
#9
print("first", end="");print("second")
#기본적으로 print함수의 출력에는 끝에 \n이 삽입됨(C는 아님)
# Out:
# firstsecond

# %%
#10
print(5/3)
# Out:
# 1.6666666666666667

# %%
#11
삼성전자 = 50000
print(str(삼성전자*10)+"원")
# Out:
# 500000원

# %%
#12
시가총액 = 298000000000000
현재가 = 50000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 298000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
#13
s = "hello"
t = "python"

print(s+"!",t)
# Out:
# hello! python

# %%
#14
8
print(2+2*3)
#코드에도 사칙연산의 순서는 적용됨
# Out:
# 8

# %%
#15
a = "132"
print(type(a))
# Out:
# <class 'str'>

# %%
#16
num_str = "720"
num_str = int(num_str)
print(type(num_str))
# Out:
# <class 'int'>

# %%
#17
num = 100
num = str(num)
print(type(num))
# Out:
# <class 'str'>

# %%
#18
stf = "15.79"
stf = float(stf)
print(type(stf))
# Out:
# <class 'float'>

# %%
#19
year = "2020"
year = int(year)
print(year-1,year,year+1)
# Out:
# 2019 2020 2021

# %%
#20
price = int("48584")
term = int("36")
print("총 금액 :", price*term)
# Out:
# 총 금액 : 1749024

# %%
#21
letters = 'python'
print(letters[0], letters[2])
# Out:
# p t

# %%
#22
license_plate = "24가 2210"
print(license_plate[-4:])
# Out:
# 2210

# %%
#23
string = "홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀

# %%
#24
string = "PYTHON"
print(string[::-1])
# Out:
# NOHTYP

# %%
#25
phone_number = "010-1111-2222"
print(phone_number.replace("-"," "))
# Out:
# 010 1111 2222

# %%
#26
phone_number = "010-1111-2222"
print(phone_number.replace("-",""))
# Out:
# 01011112222

# %%
#27
url = "http://sharebook.kr"
domain = url.split(".")[-1]
print(domain)
# Out:
# kr

# %%
#28
lang = 'python'
lang[0] = 'P'
print(lang)

#str은 수정 불가
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-b039bb2e8c02> in <module>()
#       1 #28
#       2 lang = 'python'
# ----> 3 lang[0] = 'P'
#       4 print(lang)
#       5
#
# TypeError: 'str' object does not support item assignment

# %%
#29
string = 'abcdfe2a354a32a'
print(string.replace('a','A'))
# Out:
# Abcdfe2A354A32A

# %%
#30
string = 'abcd'
string.replace('b', 'B')
print(string)
#수정값 저장 안했기 때문에 그대로
# Out:
# abcd

# %%
#31
a = "3"
b = "4"
print(a + b)
#34,str + str
# Out:
# 34

# %%
#32
print("Hi" * 3)
#HiHiHi, str * 3
# Out:
# HiHiHi

# %%
#33
print("-"*80)
# Out:
# --------------------------------------------------------------------------------

# %%
#34
t1 = "python"
t2 = "java"
print((t1+" "+t2+" ")*4)
# Out:
# python java python java python java python java

# %%
#35
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13

print("이름: %s 나이: %d\n이름: %s 나이: %d" %(name1, age1, name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
#36
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13

print("이름: {} 나이: {}\n이름: {} 나이: {}" .format(name1, age1, name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
#37
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13

print(f"이름: {name1} 나이: {age1}\n이름: {name2} 나이: {age2}")
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
#38
상장주식수 = "5,969,782,550"
상장주식수 = int(상장주식수.replace(",", ""))
print(상장주식수,type(상장주식수))
# Out:
# 5969782550 <class 'int'>

# %%
#39
분기 = "2020/03(E) (IFRS연결)"
print(분기[:7])
# Out:
# 2020/03

# %%
#40
data = "    삼성전자    "
print(data.strip())
# Out:
# 삼성전자

# %%
#41
ticker = "btc_krw"
print(ticker.upper())
# Out:
# BTC_KRW

# %%
#42
ticker = "BTX_KRW"
print(ticker.lower())
# Out:
# btx_krw

# %%
#43
string = 'hello'
print(string.capitalize())
# Out:
# Hello

# %%
#44
file_name = "보고서.xlsx"
print(file_name.endswith("xlsx"))
# Out:
# True

# %%
#45
file_name = "보고서.xlsx"
file_name.endswith(("xlsx", "xls"))
# | & = 연산자는 아니었던 걸로
# Out:
# True

# %%
#46
file_name = "2020_보고서.xlsx"
file_name.startswith("2020")
# Out:
# True

# %%
#47
a = "hello world"
print(a.split())
# Out:
# ['hello', 'world']

# %%
#48
ticker = "btc_krw"
print(ticker.split('_'))
# Out:
# ['btc', 'krw']

# %%
#49
date = "2020-05-01"
date = date.split('-')
print(f'{date[0]}년 {date[1]}월 {date[2]}일')
# Out:
# 2020년 05월 01일

# %%
#50
data = "039490     "
print(data.rstrip())
#마찬가지로 lstrip도 가능
# Out:
# 039490
